# %%
#Gmap implementation
	
import gmaps
import gmaps.datasets

gmaps.configure(api_key="AIzaSyCTTVdEJkMhjMEMwyreTvV4tgoo1Fdh998")
fig = gmaps.figure(map_type='SATELLITE')
# generate some (latitude, longitude) pairs

locations = [(51.5, 0.1), (51.7, 0.2), (51.4, -0.2), (51.49, 0.1)]
heatmap_layer = gmaps.heatmap_layer(locations)
fig.add_layer(heatmap_layer)
fig
# Out:
# Figure(layout=FigureLayout(height=u'420px'))

# %%
import gmaps
import gmaps.datasets

gmaps.configure(api_key='AIzaSyCTTVdEJkMhjMEMwyreTvV4tgoo1Fdh998')
earthquake_df = gmaps.datasets.load_dataset_as_df('earthquakes')
earthquake_df.head()

locations = earthquake_df[['latitude', 'longitude']]
weights = earthquake_df['magnitude']
fig = gmaps.figure()
fig.add_layer(gmaps.heatmap_layer(locations, weights=weights))
fig
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-516a1236fda0> in <module>()
#       3
#       4 gmaps.configure(api_key='AIzaSyCTTVdEJkMhjMEMwyreTvV4tgoo1Fdh998')
# ----> 5 earthquake_df = gmaps.datasets.load_dataset_as_df('earthquakes')
#       6 earthquake_df.head()
#       7
#
# /usr/local/lib/python2.7/dist-packages/gmaps/datasets/datasets.pyc in load_dataset_as_df(dataset_name)
#     132     Fetch a dataset, returning a pandas dataframe.
#     133     """
# --> 134     import pandas as pd
#     135     data = load_dataset(dataset_name)
#     136     headers = dataset_metadata(dataset_name)["headers"]
#
# ImportError: No module named pandas

# %%
import gmaps
import gmaps.datasets

gmaps.configure(api_key='AIzaSyCTTVdEJkMhjMEMwyreTvV4tgoo1Fdh998')
earthquake_df = gmaps.datasets.load_dataset_as_df('earthquakes')
earthquake_df.head()
# Out:
#     latitude   longitude  magnitude
# 0  65.193300 -149.072500       1.70
# 1  38.791832 -122.780830       2.10
# 2  38.818001 -122.792168       0.48
# 3  33.601667 -116.727667       0.78
# 4  37.378334 -118.520836       3.64

# %%
import gmaps
import utm
import numpy as np


gmaps.configure(api_key='AIzaSyCTTVdEJkMhjMEMwyreTvV4tgoo1Fdh998')

#Coordenadas de estaciones
GRGR = (12.13, -61.65) 
BIM = (14.52, -61.07) 
SAM = (14.84, -61.16)
SDV = (8.88, -70.6) 

#Convercion a utm
GRGR_utm = utm.from_latlon(GRGR[0],GRGR[1])
print(GRGR_utm)

BIM_utm = utm.from_latlon(BIM[0],BIM[1])
print(BIM_utm)

SAM_utm = utm.from_latlon(SAM[0],SAM[1])
print(SAM_utm)

SDV_utm = utm.from_latlon(SDV[0],SDV[1])
print(SAM_utm)

#creamos circunferencias alrededor de la estacion

 #Generador de espacio de variable
num_segmentos = 50
rGR = 253524
rBIM= 451451
rSAM= 491481
rSDV= 886223
dotsGR=[]
dotsBIM=[]
dotsSAM=[]
dotsSDV=[]

angulo = np.linspace(0, 2*np.pi, num_segmentos+1)
        
    #Coordenadas circunferencia GRGR
x = rGR * np.cos(angulo) + GRGR_utm[0]
y = rGR * np.sin(angulo) + GRGR_utm[1]

for i in range(len(x)):
    dotsGR.append(i)
    dotsGR[i]=utm.to_latlon(x[i],y[i],GRGR_utm[2],GRGR_utm[3])
    
    #Coordenadas circunferencia BIM
x = rBIM * np.cos(angulo) + BIM_utm[0]
y = rBIM * np.sin(angulo) + BIM_utm[1]

for i in range(len(x)):
    dotsBIM.append(i)
    X = x[i]
    Y = y[i]
    numZ = BIM_utm[2]
    leterZ = BIM_utm[3]
    #print("x",x[i])
    #print("y",y[i])
    if X > 999999.999 :
        X = x[i]-999999.999+rBIM-100000
        #print("x",X)
        numZ = 21
        if X < 100000.000 :
            X = 100000.000
        
    if Y > 9999999.999 :
        Y = y[i]-9999999.999
        #print("y",Y)
        leterZ = 'Q'
        
    dotsBIM[i]=utm.to_latlon(X,Y,numZ,leterZ)
    
      #Coordenadas circunferencia SAM
x = rSAM * np.cos(angulo) + SAM_utm[0]
y = rSAM * np.sin(angulo) + SAM_utm[1]

for i in range(len(x)):
    dotsSAM.append(i)
    X = x[i]
    Y = y[i]
    numZ = SAM_utm[2]
    leterZ = SAM_utm[3]
    #print("x",x[i])
    #print("y",y[i])
    if X > 999999.999 :
        X = x[i]-999999.999+rSAM-100000
        #print("x",X)
        numZ = 21
        if X < 100000.000 :
            X = 100000.000
        
    if Y > 9999999.999 :
        Y = y[i]-9999999.999
        #print("y",Y)
        leterZ = 'Q'
        
    dotsSAM[i]=utm.to_latlon(X,Y,numZ,leterZ)

#Coordenadas circunferencia SDV
x = rSDV * np.cos(angulo) + SDV_utm[0]
y = rSDV * np.sin(angulo) + SDV_utm[1]

for i in range(len(x)):
    dotsSDV.append(i)
    X = x[i]
    Y = y[i]
    numZ = SDV_utm[2]
    leterZ = SDV_utm[3]
    #print("x",x[i])
    #print("y",y[i])
    if X > 999999.999 :
        X = x[i]-999999.999+rSDV-550000
        #print("condicion x",X)
        numZ = 20
        if X < 100000.000 :
            X = 100000.000
    if X < 100000.000 :
            X = 100000.000
            
    if Y > 9999999.999 :
        Y = y[i]-9999999.999
        #print("y",Y)
        leterZ = 'Q'
    #print("x",X)
    #print("y",Y) 
    dotsSDV[i]=utm.to_latlon(X,Y,numZ,leterZ)
    
# Info estaciones
Estaciones_sismologicas = [
    {'name': 'GRGR', 'location': GRGR, 'elev': 195},
    {'name': 'BIM', 'location': BIM, 'elev': 391},
    {'name': 'SAM', 'location': SAM, 'elev': 485},
    {'name': 'SDV', 'location': SDV, 'elev': 1620}
]

stations_locations = [station['location'] for station in Estaciones_sismologicas]
info_box_template = """
<dl>
<dt>Name</dt><dd>{name}</dd>
<dt>Elevacion</dt><dd>{elev}m</dd>
</dl>
"""

station_info = [info_box_template.format(**station) for station in Estaciones_sismologicas]

#LAYERS
marker_layer = gmaps.marker_layer(stations_locations, info_box_content=station_info)
circleGR_layer = gmaps.symbol_layer(dotsGR, fill_color='red', stroke_color='red', scale=2)
circleBIM_layer = gmaps.symbol_layer(dotsBIM, fill_color='red', stroke_color='blue', scale=2)
circleSAM_layer = gmaps.symbol_layer(dotsSAM, fill_color='red', stroke_color='yellow', scale=2)
circleSDV_layer = gmaps.symbol_layer(dotsSDV, fill_color='red', stroke_color='white', scale=2)
#MAP
fig = gmaps.figure(map_type='TERRAIN')
fig.add_layer(marker_layer)
fig.add_layer(circleGR_layer)
fig.add_layer(circleBIM_layer)
fig.add_layer(circleSAM_layer)
fig.add_layer(circleSDV_layer)
fig
# Out:
# (646901.4505819345, 1341292.5583842045, 20, 'P')
# (707979.6396991496, 1606115.4476856536, 20, 'P')
# (697989.8330474463, 1641443.8516188692, 20, 'P')
# (697989.8330474463, 1641443.8516188692, 20, 'P')
# Figure(layout=FigureLayout(height='420px'))
